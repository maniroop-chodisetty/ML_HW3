# %%
import numpy as np
import pandas as pd
import scipy 
import sklearn
from collections import Counter
from sklearn.metrics import multilabel_confusion_matrix
from scipy import spatial

data = pd.read_csv('/Users/maniroop/Downloads/kmeans_data/data.csv')
labels = pd.read_csv('/Users/maniroop/Downloads/kmeans_data/label.csv',names=['label'],header=None)

data.head()

data.count()

#Data splitting step
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split( data, test_size=0.08, random_state=42)
train_labels, test_labels = train_test_split( labels, test_size=0.08, random_state=42)

class KMeans:
    
    def SSE_calculation(self, centroid_value_dict, centroid_dict,data):
        sse_data = 0
        for i in centroid_dict:
            sse_cluster = 0
            for j in centroid_dict[i]:
                dp = list(data.iloc[int(j)])
                for a,b in zip(centroid_value_dict[i],dp):
                    sse_cluster += (a-b)**2
            sse_data+=sse_cluster
        return sse_data    
    
    def Centroids_initializing(self,data,K):
        m = data.shape[0]
        centroid_value_dict={}
        for i in range(K):
            r = np.random.randint(0, m-1)
            centroid_value_dict[i] = data.iloc[r]
        return centroid_value_dict
    
    def jaccard_similarity(self,centroid, dp):
        intersection = len(list(set(centroid).intersection(dp)))
        union = (len(set(centroid)) + len(set(dp))) - intersection
        return float(intersection) / union

    def Kmeans_train(self,data,K,max_iter=20,mode=1,tol=10):
        centroid_value_dict = self.Centroids_initializing(data,K)
        new_centroid_value_dict = {}
        count = 0
        centroid_dict = {}
        convergence = False
        while((count<max_iter) and not convergence):
            
            for i in list(centroid_value_dict.keys()):
                centroid_dict[i]=[]
            for i in range(data.shape[0]):
                x = data.iloc[i]
                if mode==1 :
                    distance_measure = [np.linalg.norm(x-centroid_value_dict[j])  for j in centroid_value_dict]
                    idx = np.argmin(distance_measure)
                    centroid_dict[idx].append(i)
                elif mode==2 :
                    distance_measure = [self.jaccard_similarity(list(x),centroid_value_dict[j]) for j in centroid_value_dict]
                    idx = np.argmax(distance_measure)
                    centroid_dict[idx].append(i)
                elif mode==3 :
                    distance_measure = [1-scipy.spatial.distance.cosine(x,list(centroid_value_dict[j]))  for j in centroid_value_dict]
                    idx = np.argmax(distance_measure)
                    centroid_dict[idx].append(i)
                
                prev_centroids=dict(centroid_value_dict)
                
            
            for i in centroid_dict:
                if len(centroid_dict[i]):
                    dps_centroid = centroid_dict[i]
                    centroid_value_dict[i] = np.average(data.iloc[dps_centroid],axis=0)
            
            
            current_tol=-1
            for i in centroid_value_dict:
                prev_centroid_point = prev_centroids[i]
                new_centroid_point = centroid_value_dict[i]
                change = np.sum(np.absolute(new_centroid_point-prev_centroid_point))
                current_tol = max(change, current_tol)
                
            print("Tolerance for the Iteration ",count,": ",current_tol)
            
            count+=1
            if (current_tol<10):
                convergence = True
                break
           # print("KMeans Iteration",count)
        return centroid_value_dict,centroid_dict

def prediction_labels(C, S, labels):
    '''
    Input : C -> Centroids
            S -> Set of Indicies corresponding to Centroid C
            data -> Data used to form clusters
    Output : Returns an array of size K having labels based on majority voting in the cluster
    '''
    cluster_labels = np.zeros(10,dtype=int)
    for c in C:
        labels_of_points = []
        for point in S[c]:
            labels_of_points.extend(labels.iloc[point])
        counter = Counter(labels_of_points)
        try:
            cluster_labels[c] = max(counter, key=counter.get)
        except:
            cluster_labels[c] = np.random.randint(0,9)
    return cluster_labels

def jaccard_similarity(centroid, dp):
        intersection = len(list(set(centroid).intersection(dp)))
        union = (len(set(centroid)) + len(set(dp))) - intersection
        return float(intersection) / union

def accuracy(centroids, centroid_Labels, test_data, true_labels, mode=1):
    y_true = list(true_labels['label']);
    y_pred = []
    for index in range(test_data.shape[0]):
        featureset = test_data.iloc[index]
        if mode==1:
            distances = [np.linalg.norm(featureset - centroids[centroid]) for centroid in centroids]
            classification = distances.index(min(distances))
            y_pred.append(centroid_Labels[classification])
        elif mode==2:
            similarity = [jaccard_similarity(featureset, centroids[centroid]) for centroid in centroids]
            classification = similarity.index(max(similarity))
            y_pred.append(centroid_Labels[classification]) 
        elif mode==3:
            similarity = [1 - spatial.distance.cosine(featureset, centroids[centroid]) for centroid in centroids]
            classification = similarity.index(max(similarity))
            y_pred.append(centroid_Labels[classification])
    denominator = test_data.shape[0]
    correctly_classified = 0
    for i in range(0,len(y_pred)):
        if y_true[i] == y_pred[i]:
            correctly_classified += 1
    accuracy = correctly_classified/denominator
    return accuracy

model1 = KMeans()
centroids1,clusters1 = model1.Kmeans_train(data,10, max_iter=100,mode=1)

Euclidean_SSE = model1.SSE_calculation(centroids1,clusters1,data)

print("Euclidean SSE:",Euclidean_SSE)

cluster_labels1 = prediction_labels(centroids1,clusters1,labels)
cluster_labels1

Accuracy_Euclidean = accuracy(centroids1, cluster_labels1,test_data,test_labels)
Accuracy_Euclidean

model2 = KMeans()
centroids2,clusters2 = model2.Kmeans_train(data,10, max_iter=100,mode=2)
Jaccard_SSE = model2.SSE_calculation(centroids2,clusters2,data)

print("Jacard SSE:",Jaccard_SSE)

cluster_labels2 = prediction_labels(centroids2,clusters2,labels)
cluster_labels2

Accuracy_Jaccard = accuracy(centroids2, cluster_labels2,test_data,test_labels)
Accuracy_Jaccard

model3 = KMeans()
centroids3,clusters3 = model3.Kmeans_train(data,10, max_iter = 100,mode=3)

Cosine_SSE = model3.SSE_calculation(centroids3,clusters3,data)
print("cosine SSE:",Cosine_SSE)

print("SSE of Euclidean-K-means:",Euclidean_SSE)
print("SSE of Cosine-K-means:",Cosine_SSE)
print("SSE of Jacards-K-means:",Jaccard_SSE)

cluster_labels3 = prediction_labels(centroids3,clusters3,labels)
cluster_labels3

Accuracy_Cosine = accuracy(centroids3, cluster_labels3,test_data,test_labels)
Accuracy_Euclidean
Accuracy_Jaccard
Accuracy_Cosine

print("Accuracy of Jacards-K-means:",Accuracy_Jaccard)
print("Accuracy of Euclidean-K-means:",Accuracy_Euclidean)
print("Accuracy of Cosine-K-means:",Accuracy_Cosine)
# Out:
# Tolerance for the Iteration  0 :  25140.331983805667
# Tolerance for the Iteration  1 :  5589.261320531057
# Tolerance for the Iteration  2 :  3586.32470922415
# Tolerance for the Iteration  3 :  2307.2657485598666
# Tolerance for the Iteration  4 :  2185.674797534193
# Tolerance for the Iteration  5 :  2433.143013309901
# Tolerance for the Iteration  6 :  2481.0043319545844
# Tolerance for the Iteration  7 :  2226.427518430576
# Tolerance for the Iteration  8 :  2078.1595159515955
# Tolerance for the Iteration  9 :  1277.049328494796
# Tolerance for the Iteration  10 :  747.3609585040884
# Tolerance for the Iteration  11 :  686.238155377931
# Tolerance for the Iteration  12 :  492.7691759454178
# Tolerance for the Iteration  13 :  463.58095535803506
# Tolerance for the Iteration  14 :  237.65116824488575
# Tolerance for the Iteration  15 :  197.90529894487355
# Tolerance for the Iteration  16 :  194.46528528225235
# Tolerance for the Iteration  17 :  163.48576647401407
# Tolerance for the Iteration  18 :  221.3320874489434
# Tolerance for the Iteration  19 :  301.9757867213707
# Tolerance for the Iteration  20 :  266.1503986183538
# Tolerance for the Iteration  21 :  314.85440250746376
# Tolerance for the Iteration  22 :  319.42076360243726
# Tolerance for the Iteration  23 :  298.2486633514875
# Tolerance for the Iteration  24 :  205.56608963159618
# Tolerance for the Iteration  25 :  184.1138364287239
# Tolerance for the Iteration  26 :  172.03536056014667
# Tolerance for the Iteration  27 :  152.96929737069016
# Tolerance for the Iteration  28 :  116.331551302951
# Tolerance for the Iteration  29 :  127.08486045475314
# Tolerance for the Iteration  30 :  203.90049829644562
# Tolerance for the Iteration  31 :  147.74037713030393
# Tolerance for the Iteration  32 :  136.6095828107765
# Tolerance for the Iteration  33 :  124.54825001335414
# Tolerance for the Iteration  34 :  135.00782690583858
# Tolerance for the Iteration  35 :  138.28313971130086
# Tolerance for the Iteration  36 :  129.20089604710336
# Tolerance for the Iteration  37 :  181.88290126441973
# Tolerance for the Iteration  38 :  288.1232789280581
# Tolerance for the Iteration  39 :  209.21799307958474
# Tolerance for the Iteration  40 :  163.47058823529431
# Tolerance for the Iteration  41 :  176.27604280729426
# Tolerance for the Iteration  42 :  162.102925504349
# Tolerance for the Iteration  43 :  216.01395936720064
# Tolerance for the Iteration  44 :  181.97101177109857
# Tolerance for the Iteration  45 :  209.66413266615348
# Tolerance for the Iteration  46 :  273.37152777777777
# Tolerance for the Iteration  47 :  267.08801744482713
# Tolerance for the Iteration  48 :  196.89924451489915
# Tolerance for the Iteration  49 :  217.8792101294456
# Tolerance for the Iteration  50 :  164.1358447488584
# Tolerance for the Iteration  51 :  134.96867040244518
# Tolerance for the Iteration  52 :  166.32379016101123
# Tolerance for the Iteration  53 :  138.96828992072494
# Tolerance for the Iteration  54 :  97.06598397652897
# Tolerance for the Iteration  55 :  140.28201011718718
# Tolerance for the Iteration  56 :  165.0194063926942
# Tolerance for the Iteration  57 :  119.44369035160352
# Tolerance for the Iteration  58 :  172.9913078599386
# Tolerance for the Iteration  59 :  176.8272347896235
# Tolerance for the Iteration  60 :  206.3709505953673
# Tolerance for the Iteration  61 :  213.23601282136698
# Tolerance for the Iteration  62 :  159.5297042774161
# Tolerance for the Iteration  63 :  195.01029748283736
# Tolerance for the Iteration  64 :  169.07867055436623
# Tolerance for the Iteration  65 :  216.8757644601405
# Tolerance for the Iteration  66 :  284.74299065420564
# Tolerance for the Iteration  67 :  335.29313474877085
# Tolerance for the Iteration  68 :  235.94156680295126
# Tolerance for the Iteration  69 :  308.8506149162454
# Tolerance for the Iteration  70 :  176.95566462869013
# Tolerance for the Iteration  71 :  235.23120732864334
# Tolerance for the Iteration  72 :  238.79661722515937
# Tolerance for the Iteration  73 :  328.57707159924905
# Tolerance for the Iteration  74 :  214.3217592592593
# Tolerance for the Iteration  75 :  188.77659220634322
# Tolerance for the Iteration  76 :  186.79779365642503
# Tolerance for the Iteration  77 :  160.60669987489197
# Tolerance for the Iteration  78 :  125.52855277975124
# Tolerance for the Iteration  79 :  72.63911525029096
# Tolerance for the Iteration  80 :  71.51618940815149
# Tolerance for the Iteration  81 :  54.20477642276419
# Tolerance for the Iteration  82 :  61.412962962962766
# Tolerance for the Iteration  83 :  81.26176512065015
# Tolerance for the Iteration  84 :  163.97543427017922
# Tolerance for the Iteration  85 :  286.1565549728224
# Tolerance for the Iteration  86 :  239.9657699738142
# Tolerance for the Iteration  87 :  259.3432147358415
# Tolerance for the Iteration  88 :  286.38179778212657
# Tolerance for the Iteration  89 :  235.65961210543446
# Tolerance for the Iteration  90 :  207.5753311493721
# Tolerance for the Iteration  91 :  190.41331948158575
# Tolerance for the Iteration  92 :  111.294515198652
# Tolerance for the Iteration  93 :  110.69755631399326
# Tolerance for the Iteration  94 :  135.56164065808767
# Tolerance for the Iteration  95 :  171.20351129422386
# Tolerance for the Iteration  96 :  129.88401878728973
# Tolerance for the Iteration  97 :  169.9354142204828
# Tolerance for the Iteration  98 :  209.31771428571435
# Tolerance for the Iteration  99 :  166.05984332845762
# Euclidean SSE: 25412468441.059338
# Tolerance for the Iteration  0 :  31840.468181818185
# Tolerance for the Iteration  1 :  5869.849001655863
# Tolerance for the Iteration  2 :  3920.0380656727716
# Tolerance for the Iteration  3 :  2115.7227195160463
# Tolerance for the Iteration  4 :  1888.9880733296259
# Tolerance for the Iteration  5 :  1025.5685448448767
# Tolerance for the Iteration  6 :  1160.2459600141322
# Tolerance for the Iteration  7 :  987.6229321196472
# Tolerance for the Iteration  8 :  1226.230438043804
# Tolerance for the Iteration  9 :  1002.5146875439932
# Tolerance for the Iteration  10 :  617.3428805216388
# Tolerance for the Iteration  11 :  497.52112483975674
# Tolerance for the Iteration  12 :  554.7549039974683
# Tolerance for the Iteration  13 :  0.0
# Jacard SSE: 34361687572.938736
# Tolerance for the Iteration  0 :  25963.0231884058
# Tolerance for the Iteration  1 :  5910.396048632219
# Tolerance for the Iteration  2 :  2706.9781580475
# Tolerance for the Iteration  3 :  1684.5672201698048
# Tolerance for the Iteration  4 :  1051.5338624790938
# Tolerance for the Iteration  5 :  1118.2826207782255
# Tolerance for the Iteration  6 :  1081.0046690105173
# Tolerance for the Iteration  7 :  1606.35661168577
# Tolerance for the Iteration  8 :  1931.1246200607902
# Tolerance for the Iteration  9 :  1732.0446691990398
# Tolerance for the Iteration  10 :  1268.9044240730454
# Tolerance for the Iteration  11 :  707.5932711028036
# Tolerance for the Iteration  12 :  431.38251516974583
# Tolerance for the Iteration  13 :  384.9630015222098
# Tolerance for the Iteration  14 :  395.2400012906023
# Tolerance for the Iteration  15 :  293.124886190837
# Tolerance for the Iteration  16 :  302.97474747474746
# Tolerance for the Iteration  17 :  273.2452270830436
# Tolerance for the Iteration  18 :  203.6653415301361
# Tolerance for the Iteration  19 :  218.60037923392332
# Tolerance for the Iteration  20 :  250.99656377996223
# Tolerance for the Iteration  21 :  129.41774230414535
# Tolerance for the Iteration  22 :  171.1471820862063
# Tolerance for the Iteration  23 :  174.59422912652212
# Tolerance for the Iteration  24 :  149.9338028169015
# Tolerance for the Iteration  25 :  109.29970021465358
# Tolerance for the Iteration  26 :  101.84050764614808
# Tolerance for the Iteration  27 :  61.01084994222975
# Tolerance for the Iteration  28 :  42.270683693975805
# Tolerance for the Iteration  29 :  77.04979979980001
# Tolerance for the Iteration  30 :  61.64089937395009
# Tolerance for the Iteration  31 :  73.76553287981854
# Tolerance for the Iteration  32 :  44.526553273887885
# Tolerance for the Iteration  33 :  0.0
# cosine SSE: 25505365259.77688
# SSE of Euclidean-K-means: 25412468441.059338
# SSE of Cosine-K-means: 25505365259.77688
# SSE of Jacards-K-means: 34361687572.938736
# Accuracy of Jacards-K-means: 0.1075
# Accuracy of Euclidean-K-means: 0.08375
# Accuracy of Cosine-K-means: 0.08875

# %%
print("SSE of Euclidean-K-means:",Euclidean_SSE)
print("SSE of Cosine-K-means:",Cosine_SSE)
print("SSE of Jacards-K-means:",Jaccard_SSE)
print("Accuracy of Jacards-K-means:",Accuracy_Jaccard)
print("Accuracy of Euclidean-K-means:",Accuracy_Euclidean)
print("Accuracy of Cosine-K-means:",Accuracy_Cosine)
# Out:
# SSE of Euclidean-K-means: 25412468441.059338
# SSE of Cosine-K-means: 25505365259.77688
# SSE of Jacards-K-means: 34361687572.938736
# Accuracy of Jacards-K-means: 0.1075
# Accuracy of Euclidean-K-means: 0.08375
# Accuracy of Cosine-K-means: 0.08875
